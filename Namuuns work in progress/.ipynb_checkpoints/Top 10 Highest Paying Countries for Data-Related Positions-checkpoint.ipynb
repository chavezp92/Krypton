# %%
# Comparison of Salaries:

What are the average wages for data-related positions in different countries?

Are there significant differences in average wages for data-related positions among various countries?

How do the average wages for data-related positions compare between non-U.S. Citizens?

Are there disparities between the declared prevailing wages and the actual salaries for data-related positions?

Which countries offer the highest average wages for data-related positions?

Do specific job sub-types within data-related positions show significant variations in compensation between U.S. and non-U.S. workers?
# Out:
# Object `counterparts` not found.
# Object `employees` not found.
# Object `workers` not found.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
excel_salary = 'salary_data_states.xlsx'
df = pd.read_excel(excel_salary)

# %%
# Display the first few rows of the dataframe
pd.set_option('display.max_columns', None)
display(df.head())
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# 2                  4947000.0                           year
# 3                   251052.0                          month
# 4                    84573.0                      bi-weekly
#
#    PAID_WAGE_SUBMITTED PAID_WAGE_SUBMITTED_UNIT  \
# 0              62171.0                     year
# 1              91440.0                     year
# 2              49470.0                     year
# 3              43800.0                     year
# 4             170000.0                     year
#
#                           JOB_TITLE       WORK_CITY EDUCATION_LEVEL_REQUIRED  \
# 0                 SOFTWARE ENGINEER     BLOOMINGTON                      NaN
# 1  Assistant Professor of Marketing   SAN FRANCISCO                Doctorate
# 2         SPECIAL EDUCATION TEACHER     LOS ANGELES                      NaN
# 3                   SCIENCE TEACHER  HARLINGEN CISD                      NaN
# 4          SENIOR SOFTWARE ENGINEER        PORTLAND                      NaN
#
#   COLLEGE_MAJOR_REQUIRED EXPERIENCE_REQUIRED_Y_N  \
# 0                    NaN                     NaN
# 1              marketing                       n
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
#    EXPERIENCE_REQUIRED_NUM_MONTHS COUNTRY_OF_CITIZENSHIP  \
# 0                             NaN                    NaN
# 1                             NaN                   IRAN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
#   PREVAILING_WAGE_SOC_CODE                          PREVAILING_WAGE_SOC_TITLE  \
# 0                  15-1132                  Software Developers, Applications
# 1                  25-1011                   Business Teachers, Postsecondary
# 2                  25-2052  Special Education Teachers, Kindergarten and E...
# 3                  25-1042         Biological Science Teachers, Postsecondary
# 4                  15-1133              Software Developers, Systems Software
#
#    WORK_STATE WORK_STATE_ABBREVIATION WORK_POSTAL_CODE FULL_TIME_POSITION_Y_N  \
# 0    Illinois                      IL              NaN                      y
# 1  California                      CA          94132.0                    NaN
# 2  California                      CA              NaN                      y
# 3       Texas                      TX              NaN                      y
# 4      Oregon                      OR              NaN                      y
#
#        VISA_CLASS  PREVAILING_WAGE_PER_YEAR  PAID_WAGE_PER_YEAR  \
# 0            H-1B                       NaN             62171.0
# 1       greencard                       NaN             91440.0
# 2            H-1B                       NaN             49470.0
# 3            H-1B                       NaN             43800.0
# 4  E-3 Australian                       NaN            170000.0
#
#     JOB_TITLE_SUBGROUP  order
# 0    software engineer      1
# 1  assistant professor      2
# 2              teacher      3
# 3              teacher      4
# 4    software engineer      5

# %%
# Filter data for data-related positions
data_positions = ['data scientist', 'data analyst']
df_data = df[df['JOB_TITLE_SUBGROUP'].isin(data_positions)]

# %%
# Display the average wage by country
group_country = df_data.groupby('COUNTRY_OF_CITIZENSHIP')[['PAID_WAGE_PER_YEAR']].mean()
group_country.rename(columns={'PAID_WAGE_PER_YEAR': 'AVERAGE_WAGE'},
                     inplace=True)

display(group_country.head())
# Out:
#                          AVERAGE_WAGE
# COUNTRY_OF_CITIZENSHIP
# ALBANIA                  60000.000000
# ARGENTINA               129936.900000
# BRAZIL                   81370.000000
# BULGARIA                 70366.000000
# CANADA                   93438.333333

# %%
# Display the top 10 countries by average wage
group_country_sorted = group_country.sort_values('AVERAGE_WAGE', ascending=False)

display(group_country_sorted.head(10))
# Out:
#                          AVERAGE_WAGE
# COUNTRY_OF_CITIZENSHIP
# HUNGARY                 140000.000000
# SPAIN                   138536.000000
# UNITED KINGDOM          130000.000000
# ARGENTINA               129936.900000
# NETHERLANDS             120000.000000
# GERMANY                 116666.000000
# SINGAPORE               110000.000000
# INDIA                   106582.757303
# ITALY                   105000.220000
# FRANCE                  102738.143333

# %%
# Create a bar chart showing the top 10 highest paying countries for data-related positions
top_10_countries = group_country_sorted.head(10)

# Create bar chart
top_10_countries['AVERAGE_WAGE'].plot(kind='bar')
plt.title('Top 10 Highest Paying Countries for Data-Related Positions')
plt.xlabel('Country')
plt.ylabel('Average Wage')
plt.xticks(rotation=45)
plt.show()

# %%
# Analyze disparities in prevailing wages for U.S. and non-U.S. workers
us_workers = df_data[df_data['COUNTRY_OF_CITIZENSHIP'] == 'UNITED STATES']
non_us_workers = df_data[df_data['COUNTRY_OF_CITIZENSHIP'] != 'UNITED STATES']
# Display summary statistics
display(us_workers['PAID_WAGE_PER_YEAR'].describe())
display(non_us_workers['PAID_WAGE_PER_YEAR'].describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: PAID_WAGE_PER_YEAR, dtype: float64
# count      5067.000000
# mean      79229.784111
# std       28327.437664
# min       29411.200000
# 25%       60000.000000
# 50%       70000.000000
# 75%       91426.500000
# max      746323.000000
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
# Explore variations in compensation between U.S. and non-U.S. workers based on job sub-types or industries
group_job_subtype = df_data.groupby(['JOB_TITLE', 'COUNTRY_OF_CITIZENSHIP'])[['PAID_WAGE_PER_YEAR']].mean()
group_job_subtype.rename(columns={'PAID_WAGE_PER_YEAR': 'AVERAGE_WAGE'},
                         inplace=True)

# Display top job sub-types with variations
display(group_job_subtype.sort_values('AVERAGE_WAGE', ascending=False).head(10))
# Out:
#                                                        AVERAGE_WAGE
# JOB_TITLE                      COUNTRY_OF_CITIZENSHIP
# Technical Data Analyst         INDIA                      746323.00
# Senior Data Scientist          CHINA                      175000.00
# DATA SCIENTIST                 INDIA                      150000.00
# Sr. Big Data Analyst           HUNGARY                    140000.00
# DATA SCIENTIST                 SPAIN                      138536.00
# Data Scientist                 GERMANY                    137506.00
#                                FRANCE                     133766.43
#                                INDIA                      131397.64
# Staff Engineer, Data Scientist INDIA                      130000.00
# Data Scientist                 TAIWAN                     130000.00
