# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
excel_salary = '/Users/pedrochavez/Desktop/salary_data_states.xlsx'
df = pd.read_excel(excel_salary)

# %%
print(df.columns)
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_RECEIVED_DATE', 'DECISION_DATE',
#        'EMPLOYER_NAME', 'PREVAILING_WAGE_SUBMITTED',
#        'PREVAILING_WAGE_SUBMITTED_UNIT', 'PAID_WAGE_SUBMITTED',
#        'PAID_WAGE_SUBMITTED_UNIT', 'JOB_TITLE', 'WORK_CITY',
#        'EDUCATION_LEVEL_REQUIRED', 'COLLEGE_MAJOR_REQUIRED',
#        'EXPERIENCE_REQUIRED_Y_N', 'EXPERIENCE_REQUIRED_NUM_MONTHS',
#        'COUNTRY_OF_CITIZENSHIP', 'PREVAILING_WAGE_SOC_CODE',
#        'PREVAILING_WAGE_SOC_TITLE', 'WORK_STATE', 'WORK_STATE_ABBREVIATION',
#        'WORK_POSTAL_CODE', 'FULL_TIME_POSITION_Y_N', 'VISA_CLASS',
#        'PREVAILING_WAGE_PER_YEAR', 'PAID_WAGE_PER_YEAR', 'JOB_TITLE_SUBGROUP',
#        'order'],
#       dtype='object')

# %%
average_wage_by_employer_title = df.groupby(['EMPLOYER_NAME', 'JOB_TITLE'])['PAID_WAGE_SUBMITTED'].mean()
average_wage_by_employer_title_sorted = average_wage_by_employer_title.sort_values(ascending=False)

# %%
print(average_wage_by_employer_title_sorted)
# Out:
# EMPLOYER_NAME                             JOB_TITLE
# HUGHES HUBBARD & REED LLP                 ATTORNEY                                   2400000.000
# DLA PIPER LLP (US)                        ATTORNEY                                    825000.000
# INTUIT                                    Technical Data Analyst                      746323.000
# FROSTBURG STATE UNIVERSITY                COMPUTER SCIENCE TEACHER POSTSECONDARY      690000.000
#                                           COMPUTER SCIENCE TEACHER POST SECONDARY     690000.000
#                                                                                         ...
# INSTITUTO COMERCIAL DE PUERTO RICO        ELECTRONIC AND COMPUTER TEACHER                  8.390
# CHINESE BIBLE CHURCH INTERNATIONAL, INC.  TEACHER                                          7.414
#                                           ELEMENTARY TEACHER                               7.280
#                                           MIDDLE SCHOOL TEACHERS                           6.430
#                                           PRESCHOOL TEACHER                                5.542
# Name: PAID_WAGE_SUBMITTED, Length: 47869, dtype: float64

# %%
top_25 = average_wage_by_employer_title_sorted.head(25)

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_25.index.get_level_values('EMPLOYER_NAME'), top_25.values)
plt.xlabel('Employer Name')
plt.ylabel('Mean Paid Wage')
plt.title('Top 25 Mean Paid Wage by Employer Name and Job Title')
plt.xticks(rotation=90)
plt.show()
