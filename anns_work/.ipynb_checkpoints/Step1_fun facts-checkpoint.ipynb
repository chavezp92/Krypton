# %%
import pandas as pd
import matplotlib.pyplot as plt

excel_salary = 'salary_data_states.xlsx'
df = pd.read_excel(excel_salary)

# %%
display(df)
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
subgroups = df.groupby('JOB_TITLE_SUBGROUP').mean('PAID_WAGE_PER_YEAR')
subgroups
# Out:
#                        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# JOB_TITLE_SUBGROUP
# assistant professor                 55350.886796         90252.098263
# attorney                            91326.411022        129571.693239
# business analyst                    59356.259678         65034.262793
# data analyst                        59861.359354         66712.733880
# data scientist                      89799.037408        106977.903504
# management consultant               47947.593416         56611.346805
# software engineer                   82212.129471         90213.345693
# teacher                             37829.948856         40089.937045
#
#                        EXPERIENCE_REQUIRED_NUM_MONTHS  \
# JOB_TITLE_SUBGROUP
# assistant professor                         15.572519
# attorney                                    26.078947
# business analyst                            30.608614
# data analyst                                33.703125
# ...

# %%
visaClass = df.groupby('VISA_CLASS').mean('PAID_WAGE_PER_YEAR')
visaClass
# Out:
#                  PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# VISA_CLASS
# E-3 Australian                81984.398291         98543.116841
# H-1B                          69815.802463         80311.979947
# H-1B1 Chile                   53538.691701         62454.319864
# H-1B1 Singapore               72051.281149         82701.468919
# greencard                     88706.153209         98281.359977
#
#                  EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR  \
# VISA_CLASS
# E-3 Australian                              NaN              87669.831753
# H-1B                                        NaN              73150.091143
# H-1B1 Chile                                 NaN              58356.880272
# H-1B1 Singapore                             NaN              82421.136486
# greencard                             34.692044              88356.094222
#
#                  PAID_WAGE_PER_YEAR          order
# VISA_CLASS
# ...
